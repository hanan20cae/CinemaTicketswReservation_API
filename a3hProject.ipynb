# %% [markdown]
# <a href="https://colab.research.google.com/github/hanan20cae/CinemaTicketswReservation_API/blob/main/a3hProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip /content/djangoProjects.zip
# Out:
# Archive:  /content/djangoProjects.zip
#    creating: djangoProjects/
#    creating: djangoProjects/a3h/
#  extracting: djangoProjects/a3h/.env
#    creating: djangoProjects/a3h/a3h/
#   inflating: djangoProjects/a3h/a3h/asgi.py
#   inflating: djangoProjects/a3h/a3h/settings.py
#   inflating: djangoProjects/a3h/a3h/urls.py
#   inflating: djangoProjects/a3h/a3h/wsgi.py
#  extracting: djangoProjects/a3h/a3h/__init__.py
#    creating: djangoProjects/a3h/a3h/__pycache__/
#   inflating: djangoProjects/a3h/a3h/__pycache__/settings.cpython-310.pyc
#   inflating: djangoProjects/a3h/a3h/__pycache__/urls.cpython-310.pyc
#   inflating: djangoProjects/a3h/a3h/__pycache__/wsgi.cpython-310.pyc
#   inflating: djangoProjects/a3h/a3h/__pycache__/__init__.cpython-310.pyc
#    creating: djangoProjects/a3h/accounts/
#   inflating: djangoProjects/a3h/accounts/admin.py
#   inflating: djangoProjects/a3h/accounts/apps.py
#    creating: djangoProjects/a3h/accounts/migrations/
# ...

# %%
# !pip install django

# %%
# %cd /content/djangoProjects/a3h/
# Out:
# /content/djangoProjects/a3h

# %%
# !pip install -r /content/djangoProjects/a3h/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 83.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 67.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.5/103.5 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.1/94.1 kB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 81.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.2/304.2 kB 27.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 93.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 85.7 MB/s eta 0:00:00
# ...

# %%
# !pip install dj-rest-auth
# !pip install django-allauth
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.5/220.5 kB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for dj-rest-auth: filename=dj_rest_auth-7.0.1-py2.py3-none-any.whl size=251240 sha256=0b575a1deaf4de04363474eae6e8324c9cfc966d58b7f689ec7793a012fedc96
#   Stored in directory: /root/.cache/pip/wheels/58/96/e5/095428f7e361b01b617c65f9ff603334ed0dde032ebdc84ef0
# Successfully built dj-rest-auth
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 28.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for django-allauth: filename=django_allauth-65.9.0-py3-none-any.whl size=1850582 sha256=30ef011eeb12da87ef157654d3573dcbffcf398379773e9ce21872c4df7179fc
#   Stored in directory: /root/.cache/pip/wheels/b6/e1/e5/10d37714f73e953838413da1044ca53ca47585c950ddcea398
# Successfully built django-allauth
# ...

# %%
# !python manage.py makemigrations design
# Out:
# /usr/local/lib/python3.11/dist-packages/dj_rest_auth/registration/serializers.py:228: UserWarning: app_settings.USERNAME_REQUIRED is deprecated, use: app_settings.SIGNUP_FIELDS['username']['required']
#   required=allauth_account_settings.USERNAME_REQUIRED,
# /usr/local/lib/python3.11/dist-packages/dj_rest_auth/registration/serializers.py:230: UserWarning: app_settings.EMAIL_REQUIRED is deprecated, use: app_settings.SIGNUP_FIELDS['email']['required']
#   email = serializers.EmailField(required=allauth_account_settings.EMAIL_REQUIRED)
# /usr/local/lib/python3.11/dist-packages/dj_rest_auth/registration/serializers.py:288: UserWarning: app_settings.EMAIL_REQUIRED is deprecated, use: app_settings.SIGNUP_FIELDS['email']['required']
#   email = serializers.EmailField(required=allauth_account_settings.EMAIL_REQUIRED)
# config.json: 100% 1.36k/1.36k [00:00<00:00, 7.56MB/s]
# ...

# %%
# !python manage.py migrate
# Out:
# /usr/local/lib/python3.11/dist-packages/dj_rest_auth/registration/serializers.py:228: UserWarning: app_settings.USERNAME_REQUIRED is deprecated, use: app_settings.SIGNUP_FIELDS['username']['required']
#   required=allauth_account_settings.USERNAME_REQUIRED,
# /usr/local/lib/python3.11/dist-packages/dj_rest_auth/registration/serializers.py:230: UserWarning: app_settings.EMAIL_REQUIRED is deprecated, use: app_settings.SIGNUP_FIELDS['email']['required']
#   email = serializers.EmailField(required=allauth_account_settings.EMAIL_REQUIRED)
# /usr/local/lib/python3.11/dist-packages/dj_rest_auth/registration/serializers.py:288: UserWarning: app_settings.EMAIL_REQUIRED is deprecated, use: app_settings.SIGNUP_FIELDS['email']['required']
#   email = serializers.EmailField(required=allauth_account_settings.EMAIL_REQUIRED)
# ...

# %%
# !pip install django-cors-headers

# %%
#  ngrok يُستخدم لتوفير رابط خارجي عام لخدمة تعمل محليًا – مفيد جدًا أثناء تطوير واجهات أو اختبارات على
# Colab أو أي بيئة بدون نطاق (domain).

from pyngrok import conf, ngrok

# إدخال التوكن الخاص بـ ngrok للمصادقة (يمكن الحصول عليه من موقع ngrok.com)
conf.get_default().auth_token = "2y0qP6NCBKI9YLKCq3jpHIIkmbS_3Duieeo7dR89J1bdpWXrd"

# فتح نفق على المنفذ 8000 للحصول على رابط عام يمكن الوصول إليه من الإنترنت
public_url = ngrok.connect(8000)

# طباعة الرابط العام الذي أنشأه ngrok
print(public_url)
# Out:
# NgrokTunnel: "https://1ca5-34-169-236-7.ngrok-free.app" -> "http://localhost:8000"

# %%
# !python manage.py runserver 0.0.0.0:8000
# Out:
# Watching for file changes with StatReloader
# Performing system checks...
#
# /usr/local/lib/python3.11/dist-packages/dj_rest_auth/registration/serializers.py:228: UserWarning: app_settings.USERNAME_REQUIRED is deprecated, use: app_settings.SIGNUP_FIELDS['username']['required']
#   required=allauth_account_settings.USERNAME_REQUIRED,
# /usr/local/lib/python3.11/dist-packages/dj_rest_auth/registration/serializers.py:230: UserWarning: app_settings.EMAIL_REQUIRED is deprecated, use: app_settings.SIGNUP_FIELDS['email']['required']
#   email = serializers.EmailField(required=allauth_account_settings.EMAIL_REQUIRED)
# /usr/local/lib/python3.11/dist-packages/dj_rest_auth/registration/serializers.py:288: UserWarning: app_settings.EMAIL_REQUIRED is deprecated, use: app_settings.SIGNUP_FIELDS['email']['required']
#   email = serializers.EmailField(required=allauth_account_settings.EMAIL_REQUIRED)
# ...

# %%
# !python manage.py createsuperuser
# Out:
# /usr/local/lib/python3.11/dist-packages/dj_rest_auth/registration/serializers.py:228: UserWarning: app_settings.USERNAME_REQUIRED is deprecated, use: app_settings.SIGNUP_FIELDS['username']['required']
#   required=allauth_account_settings.USERNAME_REQUIRED,
# /usr/local/lib/python3.11/dist-packages/dj_rest_auth/registration/serializers.py:230: UserWarning: app_settings.EMAIL_REQUIRED is deprecated, use: app_settings.SIGNUP_FIELDS['email']['required']
#   email = serializers.EmailField(required=allauth_account_settings.EMAIL_REQUIRED)
# /usr/local/lib/python3.11/dist-packages/dj_rest_auth/registration/serializers.py:288: UserWarning: app_settings.EMAIL_REQUIRED is deprecated, use: app_settings.SIGNUP_FIELDS['email']['required']
#   email = serializers.EmailField(required=allauth_account_settings.EMAIL_REQUIRED)
# ...
